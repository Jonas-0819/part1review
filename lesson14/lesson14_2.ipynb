# %%
import numpy as np
t=np.arange(0,5.1,0.1)
2*np.pi*t
# Out:
# array([ 0.        ,  0.62831853,  1.25663706,  1.88495559,  2.51327412,
#         3.14159265,  3.76991118,  4.39822972,  5.02654825,  5.65486678,
#         6.28318531,  6.91150384,  7.53982237,  8.1681409 ,  8.79645943,
#         9.42477796, 10.05309649, 10.68141502, 11.30973355, 11.93805208,
#        12.56637061, 13.19468915, 13.82300768, 14.45132621, 15.07964474,
#        15.70796327, 16.3362818 , 16.96460033, 17.59291886, 18.22123739,
#        18.84955592, 19.47787445, 20.10619298, 20.73451151, 21.36283004,
#        21.99114858, 22.61946711, 23.24778564, 23.87610417, 24.5044227 ,
#        25.13274123, 25.76105976, 26.38937829, 27.01769682, 27.64601535,
#        28.27433388, 28.90265241, 29.53097094, 30.15928947, 30.78760801,
#        31.41592654])

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(0,5.1,0.1)
y1 = np.sin(2 * np.pi * t)
y2 = np.cos(2 * np.pi * t)
figure=plt.figure(figsize=(8,15))
axe1=figure.add_subplot(2,1,1)
axe2=figure.add_subplot(2,1,2)

axe1.plot(t,y1,'b-')
axe2.plot(t,y2,'r-')
plt.show

# %%
import numpy as np
import matplotlib.pyplot as plt
index = ['apple', 'banana', 'orange', 'tomato', 'guava']
values = np.array([5, 7, 3, 4, 6]) * 1000
figure=plt.figure(figsize=(8,5))
axes=figure.add_subplot(1,1,1)
axes.bar(index,values)
plt.show()
