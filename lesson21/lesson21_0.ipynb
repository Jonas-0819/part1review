# %%
import requests
from requests import ConnectionError,HTTPError,Timeout
url = 'https://data.ntpc.gov.tw/api/datasets/010E5B15-3823-4B20-B401-B1CF000550C5/json?page=0&size=2000'
try:
    response = requests.get(url)    
    response.raise_for_status()    
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生問題')

import pandas as pd
df1 = pd.DataFrame(response.json(),
                   columns=['sna','tot','sbi','sarea','ar','bemp'])

df2 = df1.rename(columns={'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還'})

#小心資料類型
df2.info()
df2
# Out:
# 沒有發生問題
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972 entries, 0 to 971
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      972 non-null    object
#  1   數量      972 non-null    object
#  2   可借      972 non-null    object
#  3   區域      972 non-null    object
#  4   地址      972 non-null    object
#  5   可還      972 non-null    object
# dtypes: object(6)
# memory usage: 45.7+ KB
#                            站名  數量  可借   區域                   地址  可還
# 0        YouBike2.0_板橋車站(新站路)  28   0  板橋區         新站路/站前路(東南側)  28
# 1    YouBike2.0_中山路二段416巷38弄口  14   5  板橋區         中山路二段326號西南側   9
# 2     YouBike2.0_濱海路一段306巷60弄  14   3  淡水區   濱海路一段306巷60弄33號(前)  11
# 3             YouBike2.0_衛教公園  14   5  淡水區           中山路158號(旁)   9
# 4      YouBike2.0_新市一路一段256巷口  21  14  淡水區       新市一路一段180號(對面)   7
# ..                        ...  ..  ..  ...                  ...  ..
# 967  YouBike2.0_捷運亞東醫院站(2號出口)  20   0  板橋區       南雅南路二段21號前方人行道  20
# 968         YouBike2.0_四川遠東路口  12   0  板橋區        四川路一段與遠東路口西南側  12
# 969           YouBike2.0_環河公園   8   3  板橋區  南雅西路二段301巷41弄(停車場旁)   5
# 970     YouBike2.0_新北市政府(新府路)  19   0  板橋區          新北市政府(新府路側)   0
# 971     YouBike2.0_新北市政府(新站路)  20   0  板橋區          新北市政府(新站路側)   0
#
# [972 rows x 6 columns]

# %%
df2[['數量', '可還', '可借']]= df2[['數量', '可還', '可借']].astype(int)

# %%
df3=df2[['區域','數量','可借','可還']]
df3
# Out:
#       區域  數量  可借  可還
# 0    板橋區  28   0  28
# 1    板橋區  14   5   9
# 2    淡水區  14   3  11
# 3    淡水區  14   5   9
# 4    淡水區  21  14   7
# ..   ...  ..  ..  ..
# 967  板橋區  20   0  20
# 968  板橋區  12   0  12
# 969  板橋區   8   3   5
# 970  板橋區  19   0   0
# 971  板橋區  20   0   0
#
# [972 rows x 4 columns]

# %%
groupby = df3.groupby(by='區域')
groupby.sum()
# Out:
#              數量   可借    可還
# 區域
# 三峽區         621  209   410
# 三芝區          50   12    38
# 三重區         990  282   702
# 中和區         938  269   665
# 五股區         170   56   112
# 八里區         162   56   106
# 土城區         911  194   702
# 坪林區          65    0     0
# 新店區         981  203   770
# 新莊區        1089  286   791
# 板橋區        2045  337  1618
# 林口區         454   99   348
# 樹林區         620  196   423
# 永和區         628  163   440
# 汐止區         686  211   473
# 泰山區         229   51   177
# 淡水區         769  214   547
# 深坑區          24   13    11
# 猴雙公共自行車專區   205    0     0
# 瑞芳區          38   14    24
# 石門區           7    5     2
# 萬里區          27   12    15
# 蘆洲區         503  133   357
# 金山區          70   23    46
# 鶯歌區         270   68   201
