# %%
import pandas as pd

df=pd.read_csv('students.csv',index_col=0)
df

# %%
#選取欄位
df['國文']

# %%
#選取多欄位
df[['國文','英文','數學']]

# %%
#陣列運算
#建立新欄位
sum = df['國文'] + df['英文'] + df['數學'] + df['地理'] + df['探索']
average = sum / 5
df['總分'] = sum
df['平均'] = average
df
# Out:
#       國文   英文   數學   地理  探索   總分    平均
# 洪阿惠   54   77   99   66  81  377  75.4
# 郭淑枝   88   83   53   54  81  359  71.8
# 臧怡君   68  100  100   74  59  401  80.2
# 楊綺芬   62   50   53   81  98  344  68.8
# 陳信宏   80   92   64   90  55  381  76.2
# 吳俐芷   74   71   52   93  96  386  77.2
# 王雅琴   61   75   52   52  82  322  64.4
# 翁鈺婷   72   67   77   51  84  351  70.2
# 游治旺   83   62   94   60  97  396  79.2
# 謝佳穎   84   61   64   64  69  342  68.4
# 溫法堯   83   76   75   88  86  408  81.6
# 吳欣書   68   77   84  100  52  381  76.2
# 王怡珊   63   99  100   52  95  409  81.8
# 藍哲嘉   97   74   63   70  85  389  77.8
# 林思賢   54   73   75   50  74  326  65.2
# 林群清   99  100  100   66  65  430  86.0
# 周琬婷   97   82   68   88  90  425  85.0
# 王怡珊   61   54   52   63  87  317  63.4
# 唐翊修   77  100   71   83  54  385  77.0
# 鍾俞禎   84   78   59   94  51  366  73.2
# 林佳慧   51   91   90   64  53  349  69.8
# 林淑安   74   78   95   69  59  375  75.0
# 吳柏誠   90   97   55   54  85  381  76.2
# ...

# %%
df.loc['王人仰',:]
# Out:
# 國文     76.0
# 英文     91.0
# 數學     55.0
# 地理     79.0
# 探索     58.0
# 總分    359.0
# 平均     71.8
# Name: 王人仰, dtype: float64

# %%
df.iloc[:5,:]
# Out:
#      國文   英文   數學  地理  探索   總分    平均
# 洪阿惠  54   77   99  66  81  377  75.4
# 郭淑枝  88   83   53  54  81  359  71.8
# 臧怡君  68  100  100  74  59  401  80.2
# 楊綺芬  62   50   53  81  98  344  68.8
# 陳信宏  80   92   64  90  55  381  76.2
