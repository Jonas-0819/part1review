# %%
import pandas as pd
df = pd.read_csv('world.csv')
df

# %%
df.info()

# %%
df1=df.reindex(columns=['洲名','國家','日期','總確診數','新增確診數','總人口數'])
df1

# %%
#依據值的搜尋
#亞洲
df1[df1['洲名']=='亞洲']

# %%
#依據值的搜尋
#台灣
dftw=df[df['國家']=='台灣']
display(dftw)

# %%
dftw['日期']>='2021-01-01'
dftw['日期']<'2022-01-01'
# Out:
# 163986     True
# 163987     True
# 163988     True
# 163989     True
# 163990     True
#           ...
# 164884    False
# 164885    False
# 164886    False
# 164887    False
# 164888    False
# Name: 日期, Length: 903, dtype: bool

# %%
dftw2021=dftw[(dftw['日期']>='2021-01-01')&(dftw['日期']<'2022-01-01')]
dftw2021

# %%
dftw2021[dftw2021['新增確診數'] >= 100]

# %%
dftw[dftw['新增確診數']>=10000]
# Out:
#             ID iso_code  洲名  國家          日期     總確診數  新增確診數  七天移動平均新增確診數  \
# 164819  164820      TWN  亞洲  台灣  2022-04-28    88446  11508     6457.571
# 164820  164821      TWN  亞洲  台灣  2022-04-29   100753  12307     7664.714
# 164821  164822      TWN  亞洲  台灣  2022-04-30   115883  15130     9226.429
# 164822  164823      TWN  亞洲  台灣  2022-05-01   132955  17072    10926.714
# 164824  164825      TWN  亞洲  台灣  2022-05-03   173942  40987    15131.429
# ...        ...      ...  ..  ..         ...      ...    ...          ...
# 164884  164885      TWN  亞洲  台灣  2022-07-02  3837856  34807    37736.143
# 164885  164886      TWN  亞洲  台灣  2022-07-03  3870528  32672    36740.429
# 164886  164887      TWN  亞洲  台灣  2022-07-04  3893643  23115    35960.286
# 164887  164888      TWN  亞洲  台灣  2022-07-05  3929627  35984    34755.571
# 164888  164889      TWN  亞洲  台灣  2022-07-06  3964188  34561    33689.286
#
#         總死亡數  新增死亡數  ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數  \
# ...
