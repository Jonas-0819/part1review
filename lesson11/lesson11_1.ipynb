# %%
import requests
from requests.exceptions import HTTPError,ConnectionError,Timeout

try:
    url = "https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/O-A0091-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
    response = requests.get(url)
    response.raise_for_status()
    content = response.text
    #print(content)
except ConnectionError:
    print("連線伺服器發生錯誤")
except Timeout:
    print("伺服器忙碌,沒有回應")
except HTTPError:
    print("伺服器回應連線錯誤")
except Exception:
    print("不知名的錯誤")
#網路上json檔下載後變成純文字檔

# %%
print(content)
#這就是純文字
# Out:
# {
#  "cwaopendata": {
#   "@xmlns": "urn:cwa:gov:tw:cwacommon:0.1",
#   "identifier": "a3aa9641-b305-4187-9f20-2260f2af921d",
#   "sender": "od@cwa.gov.tw",
#   "sent": "2025-01-27T11:22:20+08:00",
#   "status": "Actual",
#   "msgType": "Issue",
#   "dataid": "O-A0091-001",
#   "scope": "Public",
#   "dataset": {
#    "Station": [
#     {
#      "StationName": "基隆",
#      "StationId": "466940",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.135130",
#         "StationLongitude": "121.732265"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.133314",
#         "StationLongitude": "121.740475"
#        }
#       ],
#       "StationAltitude": "26.7"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.49"
#      }
#     },
#     {
#      "StationName": "淡水",
#      "StationId": "466900",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.166689",
#         "StationLongitude": "121.440690"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.164889",
#         "StationLongitude": "121.448906"
#        }
#       ],
#       "StationAltitude": "19.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.67"
#      }
#     },
#     {
#      "StationName": "新北",
#      "StationId": "466881",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.961111",
#         "StationLongitude": "121.516111"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.959328",
#         "StationLongitude": "121.524330"
#        }
#       ],
#       "StationAltitude": "24.1"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.88"
#      }
#     },
#     {
#      "StationName": "陽明山",
#      "StationId": "466930",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.163883",
#         "StationLongitude": "121.536332"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.162078",
#         "StationLongitude": "121.544547"
#        }
#       ],
#       "StationAltitude": "607.1"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.01"
#      }
#     },
#     {
#      "StationName": "鞍部",
#      "StationId": "466910",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.184391",
#         "StationLongitude": "121.521515"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.182586",
#         "StationLongitude": "121.529731"
#        }
#       ],
#       "StationAltitude": "832.6"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.39"
#      }
#     },
#     {
#      "StationName": "新竹",
#      "StationId": "467571",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.829629",
#         "StationLongitude": "121.006019"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.827853",
#         "StationLongitude": "121.014219"
#        }
#       ],
#       "StationAltitude": "26.9"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.72"
#      }
#     },
#     {
#      "StationName": "臺中",
#      "StationId": "467490",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.147495",
#         "StationLongitude": "120.675914"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.145736",
#         "StationLongitude": "120.684075"
#        }
#       ],
#       "StationAltitude": "84.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.96"
#      }
#     },
#     {
#      "StationName": "澎湖",
#      "StationId": "467350",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.567203",
#         "StationLongitude": "119.554957"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.565503",
#         "StationLongitude": "119.563094"
#        }
#       ],
#       "StationAltitude": "10.7"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "4.14"
#      }
#     },
#     {
#      "StationName": "日月潭",
#      "StationId": "467650",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.883096",
#         "StationLongitude": "120.899909"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.881325",
#         "StationLongitude": "120.908050"
#        }
#       ],
#       "StationAltitude": "1014.8"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.51"
#      }
#     },
#     {
#      "StationName": "阿里山",
#      "StationId": "467530",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.509974",
#         "StationLongitude": "120.805123"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.508208",
#         "StationLongitude": "120.813242"
#        }
#       ],
#       "StationAltitude": "2413.4"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.44"
#      }
#     },
#     {
#      "StationName": "玉山",
#      "StationId": "467550",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.489387",
#         "StationLongitude": "120.951406"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.487614",
#         "StationLongitude": "120.959522"
#        }
#       ],
#       "StationAltitude": "3844.8"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "2.06"
#      }
#     },
#     {
#      "StationName": "嘉義",
#      "StationId": "467480",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.497671",
#         "StationLongitude": "120.424783"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.495925",
#         "StationLongitude": "120.432906"
#        }
#       ],
#       "StationAltitude": "26.9"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.98"
#      }
#     },
#     {
#      "StationName": "臺南",
#      "StationId": "467410",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.994974",
#         "StationLongitude": "120.196676"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.993239",
#         "StationLongitude": "120.204772"
#        }
#       ],
#       "StationAltitude": "40.8"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "3.70"
#      }
#     },
#     {
#      "StationName": "高雄",
#      "StationId": "467441",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.732202",
#         "StationLongitude": "120.304461"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.730432",
#         "StationLongitude": "120.312516"
#        }
#       ],
#       "StationAltitude": "11.8"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.96"
#      }
#     },
#     {
#      "StationName": "恆春",
#      "StationId": "467590",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.005659",
#         "StationLongitude": "120.738307"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.003897",
#         "StationLongitude": "120.746339"
#        }
#       ],
#       "StationAltitude": "22.3"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.10"
#      }
#     },
#     {
#      "StationName": "宜蘭",
#      "StationId": "467080",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.765792",
#         "StationLongitude": "121.748343"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.763975",
#         "StationLongitude": "121.756528"
#        }
#       ],
#       "StationAltitude": "7.4"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.79"
#      }
#     },
#     {
#      "StationName": "花蓮",
#      "StationId": "466990",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.976936",
#         "StationLongitude": "121.605138"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.975128",
#         "StationLongitude": "121.613275"
#        }
#       ],
#       "StationAltitude": "16.1"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.42"
#      }
#     },
#     {
#      "StationName": "成功",
#      "StationId": "467610",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.099281",
#         "StationLongitude": "121.365342"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.097486",
#         "StationLongitude": "121.373428"
#        }
#       ],
#       "StationAltitude": "33.3"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.07"
#      }
#     },
#     {
#      "StationName": "臺東",
#      "StationId": "467660",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.753994",
#         "StationLongitude": "121.146517"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.752211",
#         "StationLongitude": "121.154586"
#        }
#       ],
#       "StationAltitude": "9.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.97"
#      }
#     },
#     {
#      "StationName": "大武",
#      "StationId": "467540",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.357445",
#         "StationLongitude": "120.895740"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.355675",
#         "StationLongitude": "120.903789"
#        }
#       ],
#       "StationAltitude": "8.1"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.01"
#      }
#     },
#     {
#      "StationName": "蘭嶼",
#      "StationId": "467620",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.038771",
#         "StationLongitude": "121.550317"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "22.036969",
#         "StationLongitude": "121.558339"
#        }
#       ],
#       "StationAltitude": "324.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.79"
#      }
#     },
#     {
#      "StationName": "彭佳嶼",
#      "StationId": "466950",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.629811",
#         "StationLongitude": "122.071506"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.627975",
#         "StationLongitude": "122.079744"
#        }
#       ],
#       "StationAltitude": "99.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.28"
#      }
#     },
#     {
#      "StationName": "東吉島",
#      "StationId": "467300",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.258657",
#         "StationLongitude": "119.659350"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.256950",
#         "StationLongitude": "119.667467"
#        }
#       ],
#       "StationAltitude": "44.5"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.91"
#      }
#     },
#     {
#      "StationName": "南沙島",
#      "StationId": "469020",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "10.371770",
#         "StationLongitude": "114.356682"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "10.370203",
#         "StationLongitude": "114.364286"
#        }
#       ],
#       "StationAltitude": "4.5"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "5.31"
#      }
#     },
#     {
#      "StationName": "東沙島",
#      "StationId": "468100",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "20.702420",
#         "StationLongitude": "116.722007"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "20.700856",
#         "StationLongitude": "116.730000"
#        }
#       ],
#       "StationAltitude": "4.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "11.08"
#      }
#     },
#     {
#      "StationName": "永康",
#      "StationId": "467420",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.040122",
#         "StationLongitude": "120.228602"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.038386",
#         "StationLongitude": "120.236700"
#        }
#       ],
#       "StationAltitude": "8.1"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "2.29"
#      }
#     },
#     {
#      "StationName": "臺北",
#      "StationId": "466920",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.039410",
#         "StationLongitude": "121.506676"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.037658",
#         "StationLongitude": "121.514853"
#        }
#       ],
#       "StationAltitude": "6.3"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.67"
#      }
#     },
#     {
#      "StationName": "金門",
#      "StationId": "467110",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.408935",
#         "StationLongitude": "118.281080"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.407306",
#         "StationLongitude": "118.289281"
#        }
#       ],
#       "StationAltitude": "48.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "5.71"
#      }
#     },
#     {
#      "StationName": "馬祖",
#      "StationId": "467990",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "26.170981",
#         "StationLongitude": "119.915113"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "26.169269",
#         "StationLongitude": "119.923419"
#        }
#       ],
#       "StationAltitude": "97.8"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "6.23"
#      }
#     },
#     {
#      "StationName": "新屋",
#      "StationId": "467050",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.008503",
#         "StationLongitude": "121.039267"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.006744",
#         "StationLongitude": "121.047486"
#        }
#       ],
#       "StationAltitude": "20.6"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.00"
#      }
#     },
#     {
#      "StationName": "田中",
#      "StationId": "467270",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.875560",
#         "StationLongitude": "120.573150"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.873802",
#         "StationLongitude": "120.581287"
#        }
#       ],
#       "StationAltitude": "42.2"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.80"
#      }
#     },
#     {
#      "StationName": "後龍",
#      "StationId": "467280",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.650318",
#         "StationLongitude": "120.823641"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "24.648563",
#         "StationLongitude": "120.831834"
#        }
#       ],
#       "StationAltitude": "30.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "1.64"
#      }
#     },
#     {
#      "StationName": "古坑",
#      "StationId": "467290",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.635401",
#         "StationLongitude": "120.543769"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.633639",
#         "StationLongitude": "120.551889"
#        }
#       ],
#       "StationAltitude": "90.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.69"
#      }
#     },
#     {
#      "StationName": "萬大發電廠",
#      "StationId": "42HA10",
#      "ObsTime": {
#       "DateTime": "2025-01-27T11:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.980611",
#         "StationLongitude": "121.131497"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "23.978875",
#         "StationLongitude": "121.139639"
#        }
#       ],
#       "StationAltitude": "1000.0"
#      },
#      "WeatherElement": {
#       "SolarRadiation": "0.42"
#      }
#     }
#    ]
#   }
#  }
# }

# %%
import io
import json
from pprint import pprint
file = io.StringIO(content)
#print(type(file))
contents = json.load(file)

# %%
date:str = contents['cwaopendata']['sent']

# %%
stations:list = contents['cwaopendata']['dataset']['Station']
pprint(stations)
# Out:
# [{'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.135130',
#                                'StationLongitude': '121.732265'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.133314',
#                                'StationLongitude': '121.740475'}],
#               'StationAltitude': '26.7'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466940',
#   'StationName': '基隆',
#   'WeatherElement': {'SolarRadiation': '0.49'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.166689',
#                                'StationLongitude': '121.440690'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.164889',
#                                'StationLongitude': '121.448906'}],
#               'StationAltitude': '19.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466900',
#   'StationName': '淡水',
#   'WeatherElement': {'SolarRadiation': '0.67'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.961111',
#                                'StationLongitude': '121.516111'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.959328',
#                                'StationLongitude': '121.524330'}],
#               'StationAltitude': '24.1'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466881',
#   'StationName': '新北',
#   'WeatherElement': {'SolarRadiation': '0.88'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.163883',
#                                'StationLongitude': '121.536332'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.162078',
#                                'StationLongitude': '121.544547'}],
#               'StationAltitude': '607.1'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466930',
#   'StationName': '陽明山',
#   'WeatherElement': {'SolarRadiation': '1.01'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.184391',
#                                'StationLongitude': '121.521515'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.182586',
#                                'StationLongitude': '121.529731'}],
#               'StationAltitude': '832.6'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466910',
#   'StationName': '鞍部',
#   'WeatherElement': {'SolarRadiation': '0.39'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.829629',
#                                'StationLongitude': '121.006019'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.827853',
#                                'StationLongitude': '121.014219'}],
#               'StationAltitude': '26.9'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467571',
#   'StationName': '新竹',
#   'WeatherElement': {'SolarRadiation': '0.72'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.147495',
#                                'StationLongitude': '120.675914'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.145736',
#                                'StationLongitude': '120.684075'}],
#               'StationAltitude': '84.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467490',
#   'StationName': '臺中',
#   'WeatherElement': {'SolarRadiation': '0.96'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.567203',
#                                'StationLongitude': '119.554957'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.565503',
#                                'StationLongitude': '119.563094'}],
#               'StationAltitude': '10.7'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467350',
#   'StationName': '澎湖',
#   'WeatherElement': {'SolarRadiation': '4.14'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.883096',
#                                'StationLongitude': '120.899909'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.881325',
#                                'StationLongitude': '120.908050'}],
#               'StationAltitude': '1014.8'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467650',
#   'StationName': '日月潭',
#   'WeatherElement': {'SolarRadiation': '0.51'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.509974',
#                                'StationLongitude': '120.805123'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.508208',
#                                'StationLongitude': '120.813242'}],
#               'StationAltitude': '2413.4'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467530',
#   'StationName': '阿里山',
#   'WeatherElement': {'SolarRadiation': '0.44'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.489387',
#                                'StationLongitude': '120.951406'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.487614',
#                                'StationLongitude': '120.959522'}],
#               'StationAltitude': '3844.8'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467550',
#   'StationName': '玉山',
#   'WeatherElement': {'SolarRadiation': '2.06'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.497671',
#                                'StationLongitude': '120.424783'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.495925',
#                                'StationLongitude': '120.432906'}],
#               'StationAltitude': '26.9'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467480',
#   'StationName': '嘉義',
#   'WeatherElement': {'SolarRadiation': '0.98'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.994974',
#                                'StationLongitude': '120.196676'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.993239',
#                                'StationLongitude': '120.204772'}],
#               'StationAltitude': '40.8'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467410',
#   'StationName': '臺南',
#   'WeatherElement': {'SolarRadiation': '3.70'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.732202',
#                                'StationLongitude': '120.304461'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.730432',
#                                'StationLongitude': '120.312516'}],
#               'StationAltitude': '11.8'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467441',
#   'StationName': '高雄',
#   'WeatherElement': {'SolarRadiation': '1.96'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.005659',
#                                'StationLongitude': '120.738307'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.003897',
#                                'StationLongitude': '120.746339'}],
#               'StationAltitude': '22.3'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467590',
#   'StationName': '恆春',
#   'WeatherElement': {'SolarRadiation': '1.10'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.765792',
#                                'StationLongitude': '121.748343'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.763975',
#                                'StationLongitude': '121.756528'}],
#               'StationAltitude': '7.4'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467080',
#   'StationName': '宜蘭',
#   'WeatherElement': {'SolarRadiation': '0.79'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.976936',
#                                'StationLongitude': '121.605138'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.975128',
#                                'StationLongitude': '121.613275'}],
#               'StationAltitude': '16.1'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466990',
#   'StationName': '花蓮',
#   'WeatherElement': {'SolarRadiation': '1.42'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.099281',
#                                'StationLongitude': '121.365342'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.097486',
#                                'StationLongitude': '121.373428'}],
#               'StationAltitude': '33.3'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467610',
#   'StationName': '成功',
#   'WeatherElement': {'SolarRadiation': '1.07'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.753994',
#                                'StationLongitude': '121.146517'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.752211',
#                                'StationLongitude': '121.154586'}],
#               'StationAltitude': '9.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467660',
#   'StationName': '臺東',
#   'WeatherElement': {'SolarRadiation': '0.97'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.357445',
#                                'StationLongitude': '120.895740'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.355675',
#                                'StationLongitude': '120.903789'}],
#               'StationAltitude': '8.1'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467540',
#   'StationName': '大武',
#   'WeatherElement': {'SolarRadiation': '1.01'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.038771',
#                                'StationLongitude': '121.550317'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.036969',
#                                'StationLongitude': '121.558339'}],
#               'StationAltitude': '324.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467620',
#   'StationName': '蘭嶼',
#   'WeatherElement': {'SolarRadiation': '0.79'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.629811',
#                                'StationLongitude': '122.071506'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.627975',
#                                'StationLongitude': '122.079744'}],
#               'StationAltitude': '99.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466950',
#   'StationName': '彭佳嶼',
#   'WeatherElement': {'SolarRadiation': '1.28'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.258657',
#                                'StationLongitude': '119.659350'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.256950',
#                                'StationLongitude': '119.667467'}],
#               'StationAltitude': '44.5'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467300',
#   'StationName': '東吉島',
#   'WeatherElement': {'SolarRadiation': '1.91'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '10.371770',
#                                'StationLongitude': '114.356682'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '10.370203',
#                                'StationLongitude': '114.364286'}],
#               'StationAltitude': '4.5'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '469020',
#   'StationName': '南沙島',
#   'WeatherElement': {'SolarRadiation': '5.31'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '20.702420',
#                                'StationLongitude': '116.722007'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '20.700856',
#                                'StationLongitude': '116.730000'}],
#               'StationAltitude': '4.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '468100',
#   'StationName': '東沙島',
#   'WeatherElement': {'SolarRadiation': '11.08'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.040122',
#                                'StationLongitude': '120.228602'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.038386',
#                                'StationLongitude': '120.236700'}],
#               'StationAltitude': '8.1'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467420',
#   'StationName': '永康',
#   'WeatherElement': {'SolarRadiation': '2.29'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.039410',
#                                'StationLongitude': '121.506676'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.037658',
#                                'StationLongitude': '121.514853'}],
#               'StationAltitude': '6.3'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '466920',
#   'StationName': '臺北',
#   'WeatherElement': {'SolarRadiation': '0.67'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.408935',
#                                'StationLongitude': '118.281080'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.407306',
#                                'StationLongitude': '118.289281'}],
#               'StationAltitude': '48.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467110',
#   'StationName': '金門',
#   'WeatherElement': {'SolarRadiation': '5.71'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '26.170981',
#                                'StationLongitude': '119.915113'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '26.169269',
#                                'StationLongitude': '119.923419'}],
#               'StationAltitude': '97.8'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467990',
#   'StationName': '馬祖',
#   'WeatherElement': {'SolarRadiation': '6.23'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.008503',
#                                'StationLongitude': '121.039267'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.006744',
#                                'StationLongitude': '121.047486'}],
#               'StationAltitude': '20.6'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467050',
#   'StationName': '新屋',
#   'WeatherElement': {'SolarRadiation': '1.00'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.875560',
#                                'StationLongitude': '120.573150'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.873802',
#                                'StationLongitude': '120.581287'}],
#               'StationAltitude': '42.2'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467270',
#   'StationName': '田中',
#   'WeatherElement': {'SolarRadiation': '0.80'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.650318',
#                                'StationLongitude': '120.823641'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.648563',
#                                'StationLongitude': '120.831834'}],
#               'StationAltitude': '30.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467280',
#   'StationName': '後龍',
#   'WeatherElement': {'SolarRadiation': '1.64'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.635401',
#                                'StationLongitude': '120.543769'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.633639',
#                                'StationLongitude': '120.551889'}],
#               'StationAltitude': '90.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '467290',
#   'StationName': '古坑',
#   'WeatherElement': {'SolarRadiation': '0.69'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.980611',
#                                'StationLongitude': '121.131497'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.978875',
#                                'StationLongitude': '121.139639'}],
#               'StationAltitude': '1000.0'},
#   'ObsTime': {'DateTime': '2025-01-27T11:10:00+08:00'},
#   'StationId': '42HA10',
#   'StationName': '萬大發電廠',
#   'WeatherElement': {'SolarRadiation': '0.42'}}]

# %%
#for station in stations:
 #   name:str = station['StationName']
  #  weather:str = station['WeatherElement']['SolarRadiation']
  #  print(name,weather)
  #  print("====================")

# %%
class Station():
    def __init__(self,name:str,weather:float):
        self.name = name
        self.weather = weather

stations1:list = []
for station in stations:
    name:str = station['StationName']
    weather:str = station['WeatherElement']['SolarRadiation']
    station:Station = Station(name,float(weather))
    stations1.append(station)

stations1
# Out:
# [<__main__.Station at 0x7eef3260c850>,
#  <__main__.Station at 0x7eef33482550>,
#  <__main__.Station at 0x7eef334833d0>,
#  <__main__.Station at 0x7eef33483050>,
#  <__main__.Station at 0x7eef3357dc10>,
#  <__main__.Station at 0x7eef3357d110>,
#  <__main__.Station at 0x7eef3357c6d0>,
#  <__main__.Station at 0x7eef3357c610>,
#  <__main__.Station at 0x7eef3357d590>,
#  <__main__.Station at 0x7eef3357d890>,
#  <__main__.Station at 0x7eef33e6d410>,
#  <__main__.Station at 0x7eef33e6df10>,
#  <__main__.Station at 0x7eef33e6ed90>,
#  <__main__.Station at 0x7eef33e6f750>,
#  <__main__.Station at 0x7eef33e6d550>,
#  <__main__.Station at 0x7eef33e6da10>,
#  <__main__.Station at 0x7eef33e6f910>,
#  <__main__.Station at 0x7eef33e6f050>,
#  <__main__.Station at 0x7eef33e6c5d0>,
#  <__main__.Station at 0x7eef33e6ef10>,
#  <__main__.Station at 0x7eef33e6f090>,
#  <__main__.Station at 0x7eef33e6db50>,
#  <__main__.Station at 0x7eef33e6f710>,
#  <__main__.Station at 0x7eef33e6f250>,
#  <__main__.Station at 0x7eef33e6c890>,
#  <__main__.Station at 0x7eef33e6da50>,
#  <__main__.Station at 0x7eef33e6d190>,
#  <__main__.Station at 0x7eef33e6d810>,
#  <__main__.Station at 0x7eef33e6e990>,
#  <__main__.Station at 0x7eef33e6cc10>,
#  <__main__.Station at 0x7eef33e6c550>,
#  <__main__.Station at 0x7eef33e6f9d0>,
#  <__main__.Station at 0x7eef33e6d2d0>,
#  <__main__.Station at 0x7eef33e6c110>]
