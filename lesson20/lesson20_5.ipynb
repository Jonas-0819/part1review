# %%
import requests
from requests import ConnectionError,HTTPError,Timeout
url = 'https://data.ntpc.gov.tw/api/datasets/010E5B15-3823-4B20-B401-B1CF000550C5/json?page=0&size=2000'
try:
    response = requests.get(url)    
    response.raise_for_status()    
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生問題')
# Out:
# 沒有發生問題

# %%
import pandas as pd
df1=pd.DataFrame(response.json(),
                 columns=['sna','tot','sbi','sarea','ar','bemp'])
df1
# Out:
#                           sna tot sbi sarea                   ar bemp
# 0        YouBike2.0_板橋車站(新站路)  28   0   板橋區         新站路/站前路(東南側)   28
# 1    YouBike2.0_中山路二段416巷38弄口  14   5   板橋區         中山路二段326號西南側    9
# 2     YouBike2.0_濱海路一段306巷60弄  14   3   淡水區   濱海路一段306巷60弄33號(前)   11
# 3             YouBike2.0_衛教公園  14   5   淡水區           中山路158號(旁)    9
# 4      YouBike2.0_新市一路一段256巷口  21  14   淡水區       新市一路一段180號(對面)    7
# ..                        ...  ..  ..   ...                  ...  ...
# 967  YouBike2.0_捷運亞東醫院站(2號出口)  20   0   板橋區       南雅南路二段21號前方人行道   20
# 968         YouBike2.0_四川遠東路口  12   0   板橋區        四川路一段與遠東路口西南側   12
# 969           YouBike2.0_環河公園   8   3   板橋區  南雅西路二段301巷41弄(停車場旁)    5
# 970     YouBike2.0_新北市政府(新府路)  19   0   板橋區          新北市政府(新府路側)    0
# 971     YouBike2.0_新北市政府(新站路)  20   0   板橋區          新北市政府(新站路側)    0
#
# [972 rows x 6 columns]

# %%
df2 = df1.rename(columns={'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還'})
df2
# Out:
#                            站名  數量  可借   區域                   地址  可還
# 0        YouBike2.0_板橋車站(新站路)  28   0  板橋區         新站路/站前路(東南側)  28
# 1    YouBike2.0_中山路二段416巷38弄口  14   5  板橋區         中山路二段326號西南側   9
# 2     YouBike2.0_濱海路一段306巷60弄  14   3  淡水區   濱海路一段306巷60弄33號(前)  11
# 3             YouBike2.0_衛教公園  14   5  淡水區           中山路158號(旁)   9
# 4      YouBike2.0_新市一路一段256巷口  21  14  淡水區       新市一路一段180號(對面)   7
# ..                        ...  ..  ..  ...                  ...  ..
# 967  YouBike2.0_捷運亞東醫院站(2號出口)  20   0  板橋區       南雅南路二段21號前方人行道  20
# 968         YouBike2.0_四川遠東路口  12   0  板橋區        四川路一段與遠東路口西南側  12
# 969           YouBike2.0_環河公園   8   3  板橋區  南雅西路二段301巷41弄(停車場旁)   5
# 970     YouBike2.0_新北市政府(新府路)  19   0  板橋區          新北市政府(新府路側)   0
# 971     YouBike2.0_新北市政府(新站路)  20   0  板橋區          新北市政府(新站路側)   0
#
# [972 rows x 6 columns]
